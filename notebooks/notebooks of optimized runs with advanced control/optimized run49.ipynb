# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import tensorflow as tf
import os


ACC=0.1
try_num = 1

while (ACC<0.90 and try_num<50):
    # DOE factors:
    learning_rate = 0.001
    dropout_value = 0.3
    # n-conv_layers = 3
    n_units_last_layer = 2048
    n_filters_l1 = 4
    n_filters_l2 = 32
    
    # other factors:
    img_size = 130
    batch_size = 32
    validation_split = 0.1  # 10% for validation
    test_split = 0.00  # 0% for testing
    shuffle_buffer_size = 1000
    seed_num = 101
    desired_accuracy = 0.99  # it should be active if EarlyStoppingCallback is activated
    loss = 'binary_crossentropy'
    #optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    metrics = ['accuracy']
    epochs = 16
    f_mode = 'nearest'  # fill_mode in image augmentation
    
    #DATA_DIR = "D:\\CS online courses\\Free DataSets\\Free Images\\Easier portrait images_GPU_03"
    DATA_DIR = "/Users/hossein/Downloads/Easier portrait images_GPU_03"
    
    # Subdirectories for each class
    data_dir_woman = os.path.join(DATA_DIR, 'woman')
    data_dir_man = os.path.join(DATA_DIR, 'man')
    
    image_size = (img_size, img_size)  # Resize images to this size
    # Load train dataset (excluding validation & test set):
    train_dataset = tf.keras.utils.image_dataset_from_directory(
        directory = DATA_DIR,
        image_size = image_size,
        batch_size = batch_size,
        label_mode='binary',
        validation_split = validation_split + test_split,  # Total split for val + test
        subset = "training",
        seed = seed_num
    )
    # Load validation dataset
    val_dataset = tf.keras.utils.image_dataset_from_directory(
        directory = DATA_DIR,
        image_size = image_size,
        batch_size = batch_size,
        label_mode='binary',
        validation_split = validation_split + test_split,
        subset = "validation",
        seed = seed_num
    )
    # Further manually split validation dataset to extract test dataset
    val_batches = tf.data.experimental.cardinality(val_dataset)
    # Compute test dataset size (number of batches)
    test_size = round(val_batches.numpy() * (test_split / (validation_split + test_split)))
    # Split validation dataset into validation and test subsets
    test_dataset = val_dataset.take(test_size)
    val_dataset = val_dataset.skip(test_size)
    # Optimize for performance
    AUTOTUNE = tf.data.AUTOTUNE
    training_dataset = train_dataset.cache().shuffle(shuffle_buffer_size).prefetch(buffer_size = AUTOTUNE)
    validation_dataset = val_dataset.cache().prefetch(buffer_size = AUTOTUNE)
    test_dataset = test_dataset.cache().prefetch(buffer_size = AUTOTUNE)
    
    # Get the first batch of images and labels
    for images, labels in training_dataset.take(1):
    	example_batch_images = images
    	example_batch_labels = labels
    max_pixel = np.max(example_batch_images)
    
    def scheduler(epoch, lr):
        if epoch < 10:
            if epoch % 5 == 0 and epoch > 0:
                return lr / 1
            return lr
        elif epoch < 15:
            if epoch % 5 == 0 and epoch > 0:
                return lr / 2
            return lr
        elif epoch < 30:
            if epoch % 5 == 0 and epoch > 0:
                return lr / 1
            return lr
        return lr
    lr_callback = LearningRateScheduler(scheduler)
    
    # augmentation_model
    def augment_model():
        augmentation_model = tf.keras.Sequential([
            # Specify the input shape.
            tf.keras.Input(shape = (img_size, img_size, 3)),
            tf.keras.layers.RandomFlip("horizontal"),
            tf.keras.layers.RandomRotation(0.1, fill_mode = f_mode),
            #tf.keras.layers.RandomTranslation(0.1, 0.1, fill_mode = f_mode),
            #tf.keras.layers.RandomZoom(0.1, fill_mode=f_mode)
            ])
        return augmentation_model
    
    def create_and_compile_model():
        augmentation_layers = augment_model()
        model = tf.keras.Sequential([
            # Note: the input shape is the desired size of the image: 150x150 with 3 bytes for color
            tf.keras.layers.InputLayer(shape = (img_size, img_size, 3)),
            augmentation_layers,
            tf.keras.layers.Rescaling(1./255),
            #####    CONV_LAYER_1:     #####
            tf.keras.layers.Conv2D(n_filters_l1, (4, 4), activation = 'linear'),
            tf.keras.layers.MaxPooling2D(2, 2),
            #####    CONV_LAYER_2:     #####
            tf.keras.layers.Conv2D(n_filters_l2, (3, 3), activation = 'relu'),
            tf.keras.layers.MaxPooling2D(2, 2),
            #####    CONV_LAYER_3:     #####
            tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
            tf.keras.layers.MaxPooling2D(2, 2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dropout(dropout_value),
            #####    BEFORE_LAST_LAYER:     #####
            tf.keras.layers.Dense(n_units_last_layer, activation = 'relu'),
            # It will contain a value from 0-1 where 0 for the class 'female' and 1 for the 'male'
            tf.keras.layers.Dense(1, activation = 'sigmoid')]) 
        model.compile(
            loss = loss,
            optimizer = optimizer,
            metrics = metrics
        )
        return model

    # Create the compiled but untrained model
    def reset_weights(model):
        for layer in model.layers:
            if hasattr(layer, 'kernel_initializer'):
                layer.kernel.assign(layer.kernel_initializer(layer.kernel.shape))
            if hasattr(layer, 'bias_initializer'):
                layer.bias.assign(layer.bias_initializer(layer.bias.shape))

    model = create_and_compile_model()
    reset_weights(model)  # Reset all layer weights
    training_history = model.fit(training_dataset, 
                                 epochs=epochs, 
                                 validation_data=validation_dataset, 
                                 callbacks=[lr_callback], 
                                 verbose=2)
    result_history = pd.DataFrame(model.history.history)
    ACC = result_history['val_accuracy'].iloc[-1]
    print(f"Current validation accuracy: {ACC}")
    model.save('trained_model_run49_advanced_control.h5')
    # Restart script
    print("Reseting all weights...")
    print(f'Current number of trials: {try_num}')
    try_num += 1
    result_history[['loss', 'val_loss']].plot(figsize=(5, 3))
    result_history[['accuracy', 'val_accuracy']].plot(figsize=(5, 3))
    plt.show()
    print(model.metrics_names)
    print(model.evaluate(validation_dataset))
    y_true = np.concatenate([y.numpy() for _, y in validation_dataset])
    y_pred_prob = model.predict(validation_dataset)
    # Convert probabilities to class labels (0:Female or 1:Male)
    y_pred = (y_pred_prob > 0.5).astype(int).flatten()
    print("Classification Report:\n", classification_report(y_true, y_pred, target_names=['Female', 'Male']))

result_history.head(15)
# Out:
# Found 943 files belonging to 2 classes.
# Using 849 files for training.
# Found 943 files belonging to 2 classes.
# Using 94 files for validation.
# Epoch 1/16
# 2025-05-06 09:50:50.930432: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 27/27 - 2s - 88ms/step - accuracy: 0.6690 - loss: 0.6535 - val_accuracy: 0.7128 - val_loss: 0.5310 - learning_rate: 1.0000e-03
# Epoch 2/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7527 - loss: 0.5157 - val_accuracy: 0.7660 - val_loss: 0.5428 - learning_rate: 1.0000e-03
# Epoch 3/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7986 - loss: 0.4515 - val_accuracy: 0.8191 - val_loss: 0.4753 - learning_rate: 1.0000e-03
# Epoch 4/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8210 - loss: 0.3976 - val_accuracy: 0.7872 - val_loss: 0.4179 - learning_rate: 1.0000e-03
# Epoch 5/16
# 27/27 - 2s - 64ms/step - accuracy: 0.8375 - loss: 0.3676 - val_accuracy: 0.8298 - val_loss: 0.4005 - learning_rate: 1.0000e-03
# Epoch 6/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8610 - loss: 0.3525 - val_accuracy: 0.8191 - val_loss: 0.3725 - learning_rate: 1.0000e-03
# Epoch 7/16
# 27/27 - 2s - 64ms/step - accuracy: 0.8516 - loss: 0.3440 - val_accuracy: 0.8511 - val_loss: 0.4465 - learning_rate: 1.0000e-03
# Epoch 8/16
# 27/27 - 2s - 64ms/step - accuracy: 0.8610 - loss: 0.3269 - val_accuracy: 0.8404 - val_loss: 0.4465 - learning_rate: 1.0000e-03
# Epoch 9/16
# 27/27 - 2s - 66ms/step - accuracy: 0.8551 - loss: 0.3338 - val_accuracy: 0.8511 - val_loss: 0.3896 - learning_rate: 1.0000e-03
# Epoch 10/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8751 - loss: 0.2984 - val_accuracy: 0.8723 - val_loss: 0.3290 - learning_rate: 1.0000e-03
# Epoch 11/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8846 - loss: 0.2679 - val_accuracy: 0.8617 - val_loss: 0.3619 - learning_rate: 5.0000e-04
# Epoch 12/16
# 27/27 - 2s - 65ms/step - accuracy: 0.
- learning_rate: 5.0000e-04
# Epoch 14/16
# 27/27 - 2s - 66ms/step - accuracy: 0.8822 - loss: 0.2720 - val_accuracy: 0.8404 - val_loss: 0.4390 - learning_rate: 5.0000e-04
# Epoch 15/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8775 - loss: 0.2950 - val_accuracy: 0.7979 - val_loss: 0.3791 - learning_rate: 5.0000e-04
# Epoch 16/16
# 27/27 - 2s - 67ms/step - accuracy: 0.8928 - loss: 0.2585 - val_accuracy: 0.8191 - val_loss: 0.4826 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Current validation accuracy: 0.8191489577293396
# Reseting all weights...
# Current number of trials: 46
# ['loss', 'compile_metrics']
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8236 - loss: 0.5081
# [0.4826164245605469, 0.8191489577293396]
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Female       0.73      0.93      0.82        41
#         Male       0.93      0.74      0.82        53
#
#     accuracy                           0.82        94
#    macro avg       0.83      0.83      0.82        94
# weighted avg       0.84      0.82      0.82        94
#
# Found 943 files belonging to 2 classes.
# Using 849 files for training.
# Found 943 files belonging to 2 classes.
# Using 94 files for validation.
# Epoch 1/16
# 27/27 - 2s - 87ms/step - accuracy: 0.5265 - loss: 0.9787 - val_accuracy: 0.4362 - val_loss: 0.6926 - learning_rate: 1.0000e-03
# Epoch 2/16
# 27/27 - 2s - 65ms/step - accuracy: 0.6054 - loss: 0.6529 - val_accuracy: 0.6702 - val_loss: 0.6498 - learning_rate: 1.0000e-03
# Epoch 3/16
# 27/27 - 2s - 65ms/step - accuracy: 0.6902 - loss: 0.5986 - val_accuracy: 0.7553 - val_loss: 0.5225 - learning_rate: 1.0000e-03
# Epoch 4/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7527 - loss: 0.5196 - val_accuracy: 0.7872 - val_loss: 0.5367 - learning_rate: 1.0000e-03
# Epoch 5/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7644 - loss: 0.5102 - val_accuracy: 0.7447 - val_loss: 0.5795 - learning_rate: 1.0000e-03
# Epoch 6/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7903 - loss: 0.4708 - val_accuracy: 0.7234 - val_loss: 0.5307 - learning_rate: 1.0000e-03
# Epoch 7/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7703 - loss: 0.4873 - val_accuracy: 0.7979 - val_loss: 0.4810 - learning_rate: 1.0000e-03
# Epoch 8/16
# 27/27 - 2s - 66ms/step - accuracy: 0.7856 - loss: 0.4525 - val_accuracy: 0.7766 - val_loss: 0.4936 - learning_rate: 1.0000e-03
# Epoch 9/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7998 - loss: 0.4391 - val_accuracy: 0.8191 - val_loss: 0.4180 - learning_rate: 1.0000e-03
# Epoch 10/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8139 - loss: 0.4246 - val_accuracy: 0.8723 - val_loss: 0.4169 - learning_rate: 1.0000e-03
# Epoch 11/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8292 - loss: 0.3791 - val_accuracy: 0.8723 - val_loss: 0.3505 - learning_rate: 5.0000e-04
# Epoch 12/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8351 - loss: 0.3836 - val_accuracy: 0.8404 - val_loss: 0.3862 - learning_rate: 5.0000e-04
# Epoch 13/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8186 - loss: 0.3839 - val_accuracy: 0.8404 - val_loss: 0.4063 - learning_rate: 5.0000e-04
# Epoch 14/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8280 - loss: 0.3842 - val_accuracy: 0.8830 - val_loss: 0.3808 - learning_rate: 5.0000e-04
# Epoch 15/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8504 - loss: 0.3535 - val_accuracy: 0.8511 - val_loss: 0.3950 - learning_rate: 5.0000e-04
# Epoch 16/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8740 - loss: 0.3112 - val_accuracy: 0.8404 - val_loss: 0.4804 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Current validation accuracy: 0.8404255509376526
# Reseting all weights...
# Current number of trials: 47
# ['loss', 'compile_metrics']
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8147 - loss: 0.5610
# [0.4803805947303772, 0.8404255509376526]
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Female       0.84      0.78      0.81        41
#         Male       0.84      0.89      0.86        53
#
#     accuracy                           0.84        94
#    macro avg       0.84      0.83      0.84        94
# weighted avg       0.84      0.84      0.84        94
#
# Found 943 files belonging to 2 classes.
# Using 849 files for training.
# Found 943 files belonging to 2 classes.
# Using 94 files for validation.
# Epoch 1/16
# 27/27 - 2s - 88ms/step - accuracy: 0.5925 - loss: 0.7069 - val_accuracy: 0.7128 - val_loss: 0.5959 - learning_rate: 1.0000e-03
# Epoch 2/16
# 27/27 - 2s - 67ms/step - accuracy: 0.7468 - loss: 0.5055 - val_accuracy: 0.8085 - val_loss: 0.6172 - learning_rate: 1.0000e-03
# Epoch 3/16
# 27/27 - 2s - 65ms/step - accuracy: 0.7574 - loss: 0.5012 - val_accuracy: 0.8511 - val_loss: 0.4599 - learning_rate: 1.0000e-03
# Epoch 4/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8139 - loss: 0.4127 - val_accuracy: 0.8191 - val_loss: 0.4413 - learning_rate: 1.0000e-03
# Epoch 5/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8174 - loss: 0.4030 - val_accuracy: 0.8511 - val_loss: 0.4085 - learning_rate: 1.0000e-03
# Epoch 6/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8316 - loss: 0.3658 - val_accuracy: 0.8404 - val_loss: 0.4184 - learning_rate: 1.0000e-03
# Epoch 7/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8469 - loss: 0.3475 - val_accuracy: 0.8298 - val_loss: 0.3522 - learning_rate: 1.0000e-03
# Epoch 8/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8645 - loss: 0.3265 - val_accuracy: 0.8511 - val_loss: 0.3216 - learning_rate: 1.0000e-03
# Epoch 9/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8669 - loss: 0.3149 - val_accuracy: 0.8404 - val_loss: 0.3500 - learning_rate: 1.0000e-03
# Epoch 10/16
# 27/27 - 2s - 67ms/step - accuracy: 0.8681 - loss: 0.3012 - val_accuracy: 0.8830 - val_loss: 0.3195 - learning_rate: 1.0000e-03
# Epoch 11/16
# 27/27 - 2s - 65ms/step - accuracy: 0.9069 - loss: 0.2660 - val_accuracy: 0.8723 - val_loss: 0.3838 - learning_rate: 5.0000e-04
# Epoch 12/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8928 - loss: 0.2631 - val_accuracy: 0.8830 - val_loss: 0.3026 - learning_rate: 5.0000e-04
# Epoch 13/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8810 - loss: 0.2571 - val_accuracy: 0.8723 - val_loss: 0.3533 - learning_rate: 5.0000e-04
# Epoch 14/16
# 27/27 - 2s - 65ms/step - accuracy: 0.9046 - loss: 0.2509 - val_accuracy: 0.8936 - val_loss: 0.3263 - learning_rate: 5.0000e-04
# Epoch 15/16
# 27/27 - 2s - 65ms/step - accuracy: 0.9058 - loss: 0.2314 - val_accuracy: 0.8830 - val_loss: 0.3521 - learning_rate: 5.0000e-04
# Epoch 16/16
# 27/27 - 2s - 65ms/step - accuracy: 0.8916 - loss: 0.2405 - val_accuracy: 0.9043 - val_loss: 0.3639 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Current validation accuracy: 0.9042553305625916
# Reseting all weights...
# Current number of trials: 48
# ['loss', 'compile_metrics']
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8818 - loss: 0.4189
# [0.3638972342014313, 0.9042553305625916]
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Female       0.86      0.93      0.89        41
#         Male       0.94      0.89      0.91        53
#
#     accuracy                           0.90        94
#    macro avg       0.90      0.91      0.90        94
# weighted avg       0.91      0.90      0.90        94
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.592462  0.706931      0.712766  0.595866         0.0010
# 1   0.746761  0.505478      0.808511  0.617151         0.0010
# 2   0.757362  0.501167      0.851064  0.459903         0.0010
# 3   0.813899  0.412672      0.819149  0.441338         0.0010
# 4   0.817432  0.403004      0.851064  0.408463         0.0010
# 5   0.831567  0.365826      0.840426  0.418396         0.0010
# 6   0.846879  0.347481      0.829787  0.352203         0.0010
# 7   0.864547  0.326505      0.851064  0.321596         0.0010
# 8   0.866902  0.314927      0.840426  0.350007         0.0010
# 9   0.868080  0.301186      0.882979  0.319519         0.0010
# 10  0.906949  0.265967      0.872340  0.383776         0.0005
# 11  0.892815  0.263132      0.882979  0.302552         0.0005
# 12  0.881037  0.257067      0.872340  0.353307         0.0005
# 13  0.904594  0.250938      0.893617  0.326296         0.0005
# 14  0.905771  0.231422      0.882979  0.352098         0.0005
